# %%
# Import Pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# Bring GoodReads book data 
# Explore data file of books
books = pd.read_csv('books.csv')

# %%
# Print shape (rows, columns) of data file
print(books.shape)
# Out:
# (10000, 23)

# %%
# Print head
print(books.head)
# Out:
# <bound method NDFrame.head of          id   book_id  best_book_id   work_id  books_count        isbn  \
# 0         1   2767052       2767052   2792775          272   439023483
# 1         2         3             3   4640799          491   439554934
# 2         3     41865         41865   3212258          226   316015849
# 3         4      2657          2657   3275794          487    61120081
# 4         5      4671          4671    245494         1356   743273567
# 5         6  11870085      11870085  16827462          226   525478817
# 6         7      5907          5907   1540236          969   618260307
# 7         8      5107          5107   3036731          360   316769177
# 8         9       960           960   3338963          311  1416524797
# 9        10      1885          1885   3060926         3455   679783261
# 10       11     77203         77203   3295919          283  1594480001
# 11       12  13335037      13335037  13155899          210    62024035
# ...

# %%
#Make dictionary 'pub_year' with book_id and original publication year
pub_year = {'book_id': 'original_publication_year'}
type(pub_year)
# Out:
# dict

# %%
# Print column names and data type
print(books.columns)
# Note that there is no field for "genre"
# Maybe I can get an isbn data set to link and it would have genre?
# Out:
# Index(['id', 'book_id', 'best_book_id', 'work_id', 'books_count', 'isbn',
#        'isbn13', 'authors', 'original_publication_year', 'original_title',
#        'title', 'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'image_url',
#        'small_image_url'],
#       dtype='object')

# %%
# Create Histogram of publications years to see how many recent books we have
plt.hist(list(pub_year.keys()), pub_year.values(), color='g')
plt.show()
